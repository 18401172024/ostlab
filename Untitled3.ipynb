# %% [markdown]
# <a href="https://colab.research.google.com/github/18401172024/ostlab/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# sample dataset
data = {
    "Year":[2020,2021,2022,2023],
    "Users":[200,400,800,1200]
}

df = pd.DataFrame(data)

print(df)

plt.plot(df["Year"],df["Users"])
plt.title("User Growth")
plt.show()
# Out:
#    Year  Users
# 0  2020    200
# 1  2021    400
# 2  2022    800
# 3  2023   1200
